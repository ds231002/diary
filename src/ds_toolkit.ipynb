# %%
from ds_toolkit.llm import (
    get_client,
    get_response,
    get_text,
    has_tool_calls,
    get_tool_calls,
    get_reasoning,
    get_usage,
)
from ds_toolkit.files import (
    load_json,
)

# %%
response = get_response(
    client=get_client("ollama"),
    model="qwen3:8b",
    user_input="Zeig mir meinen aktuellen Stromverbrauch.",
    tools=load_json("tools.json")
)

# %% [markdown]
# # users

# %%
from db.crud.users import (
    create_user,
    list_users,
    delete_user
)

user_id = 'f9a5a2e0-21cf-4957-b91b-7a3cbd3fd9c1'

# user_id = create_user(user_name="david", is_demo=True)
# list_users()

# %%
from db.crud.tags import(
    create_tag,
    list_tags_by_user,
    get_tag_by_id,
    update_tag,
    delete_tag
)

# %%
from datetime import date

from db.crud.entries import(
    create_entry,
    get_entry_by_id,
    list_entries_by_user,
    update_entry,
    delete_entry
)

# %%
# entry = """
# Ich bin heute wieder bis in die Nacht ein Brettspiel online gespielt. Das tue ich vermutlich deshalb so gerne, weil ich da geordnete Systeme und klare Regeln habe und das sehr schätze. Ich habe mich beim Einschlafen zwar wieder selbst verurteilt warum ich es wieder so spät werden ließ und warum ich immer wieder eine neue Runde anfange. Aber da ich heute nichts vor hatte habe ich trotzdem bis Mittags gut und genug geschlafen. Allerdings ist das trotzdem nicht förderlich für den Schlafrhythmus den ich eigentlich wieder alltagstauglich und regelmäßig ausrichten möchte.

# Ich habe wieder Träume gehabt, einmal von eben diesem Brettspiel wo plötzlich im Laufe des Spiels die Regeln völlig verändert wurden und mir nicht völlig klar war wie genau. Das Spielfeld wurde komplett umgebaut. Die Folge war eine absolute Ungleichverteilung und Machtverschiebung. Das hat in mir ein sehr großes Unwohlsein ausgelöst, weil ich die Kontrolle verloren hatte, viel verloren habe, aber nicht ganz verstanden habe warum und wie sich jetzt was verändert hat.

# Danach hatte ich einen Traum wo ich in einer Schule sitze und wir eine Aufgabe erledigen mussten die mir sehr leicht viel und ich somit recht schnell fertig war. Danach beschäftigte ich mich eine Weile anders indem ich nachdachte oder irgendetwas am Handy machte. Die Lehrerin schien das zu bemerken und gab mir eine neue Aufgabe, nicht irgendwie vorwurfsvoll oder verärgert, mehr selbstverständlich und freundlich. Ich bemerkte, dass andere schon fleißig an dieser Aufgabe zu arbeiten schienen und fühlte mich abgehängt. Das machte mir etwas Druck. Die zweite Aufgabe bestand darin einen Lückentext mit bestimmten Buchstaben zu füllen. Diese Buchstaben waren aber nicht vollständig bekannt und man konnte sie irgendwie als Belohnung für irgendwelche Geschichten oder Ideen die auf dem Lückentext basieren von der Lehrerin erhalten. Ich sah einige Schüler bei denen die Lehrerein Saß die ihr irgendetwas erzählten und sie gab ihnen hinweise darauf. Das Konzept habe ich aber nicht ganz durchschaut und auch das Lernziel nicht. Ich hatte natürlich einige Vermutungen welche Buchstaben in welche Lücken gehören könnten, hatte aber eine innere Barriere diese hinzuschreiben, weil ich absolute Sicherheit brauchte um garantiert die richtige Lösung hinzuschreiben. Ich habe mich geweigert zu akzeptieren, dass es hier scheinbar um eine dynamische Lösungsfindung geht wo durch viele Fehlversuche irgendwann durch Ausschlussverfahren ein Gesamtbild entsteht mit dem man zu einer Lösung kommen könnte. Das habe ich zwar irgendwie verstanden, aber für mich war es sehr unangenehm irgendetwas hinzuschreiben was zu einem großen Teil falsch sein würde. Ich wollte ein Muster erkennen, habe es aber nicht geschafft und bin innerlich fast daran verzweifelt.
# """
# create_entry(
#     user_id,
#     start_date=date(2026, 2, 3),
#     content=entry
# )

# %%
from db.crud.entry_tags import sync_entry_tags

# %%
entry_id = "ea7811de-5125-47dd-ab91-4c539cbf7aeb"
tag_ids = ["54ede838-c560-4687-9a1e-c6a1f5ea6bcd", "47de5179-e179-4771-91fa-683b1ba79216"]

sync_entry_tags(entry_id, tag_ids)
